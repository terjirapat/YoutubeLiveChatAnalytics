# %%
import requests
import json

# Replace YOUR_VIDEO_ID with the ID of the video you want to extract comments from
# https://www.youtube.com/watch?v=4b6yYQqL8zs
video_id = "4b6yYQqL8zs" 

# Set up the YouTube API request
api_key = "AIzaSyAFGXgs05BRR4QwJjTIgf8-BiiRm1SMc-0"
api_url = "https://www.googleapis.com/youtube/v3/commentThreads"

all_comments = []

# Set up the pagination parameters
params = {
    "part": "snippet",
    "videoId": video_id,
    "key": api_key,
    "maxResults": 100,  # The maximum number of comments that can be retrieved per API request
}

# Make the initial API request
response = requests.get(api_url, params=params)

# Extract the comments from the response
comments = response.json()["items"]
all_comments += comments

# Check if there are more comments to retrieve
next_page_token = response.json().get("nextPageToken")

# Keep making API requests until all comments have been retrieved
while next_page_token:
    # Update the pagination parameters
    params["pageToken"] = next_page_token

    # Make the next API request
    response = requests.get(api_url, params=params)

    # Extract the comments from the response
    comments = response.json()["items"]
    all_comments += comments

    # Check if there are more comments to retrieve
    next_page_token = response.json().get("nextPageToken")

# Print the comments
# result = [comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"] for comment in all_comments]
for comment in all_comments:
    print(comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"])
# Out:
# S U P E R <br>A I <br>E N G I N E E R <br>(try not to cringe) (impossible)
# AI บอกสถานที่นี่พี่ป.โท ของ VISTEC ก็เริ่มทำกันแล้วนะคะ ก็ยากแหละค่ะ TvT
# ผมเรียน/ทำ AI มา 4+ ปีก็อยากแสดงความคิดเห็นซักนิด แต่มาเจอโจทย์ป้ายทะเบียนกับ NLP เข้าไปก็เงิบไปเลย ส่วนตัวทำแต่ medical images, time series, DNN ส่วน NLP กำลังเรียนอยู่ ถ้ามีตอนหน้า มีโจทย์อื่น คงจะร่วมสนทนาบ้าง
# fc master arm
# ผมขอเต้าหู้หลอดคืน
# ตอนเลข 5 ขึ้นก็นึกว่า 5 ล้าน 555
# เจคร็อป เด็กนอกสายเขียว
# อยากทำได้แบบพวกเขาจังคับ ต้องเริ่มเรียนจากอะไรคับ 😅
# ใช้ chat gpt ชนะเลิศไปเลย
# ตั้งเเต่ดูคริปนายอาร์ม ได้ยินเสียงจิ๊ดๆ เเฮ๊กๆนี่ขมวดคิ้วเลย
# ไม่มีใคร่เก่งกว่า  เพรียงแค่คุณทำไม่ดีพอ
# ชอบๆ
# รูปแบบรายการ การตัดต่อ ซาวแบ็คกราวน์ อันเดียวกับมาสเตอร์เชฟเลย555555555
# พิธีกรชายพูดฟังยากมากเลยค่ะ
# เอียนกับคำว่า AI สุดๆ
# ยอดวิวทางยูทูปแซงช่องทาง official รายการไปแระ
# เสร็จก่อนสิบนาที ลุกขึ้นมาขิง แล้วยังได้ที่หนึ่งอีก ตึงจัด
# เจคอปไม่ใช่แค่ super ai engineer แล้วแต่นี้มัน super ultra ai engineer 5555
# ...
